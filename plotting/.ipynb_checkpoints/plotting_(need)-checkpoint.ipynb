# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %%
from matplotlib import pyplot as plt
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) # format the grid, smaller no = fainter grid
plt.legend(loc='upper left')

# %%
plt.plot(x, y_2, label='Y values',
         c='red', ls='dashed',lw=2) # short form
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) # format the grid, smaller no = fainter grid
plt.legend(loc='upper left')

# %%
plt.plot(x, y_1, y_2) # including y_2 values in graph
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)

# %% [markdown]
# ## 1.2 Adding another plot

# %%
plt.plot(x, y_2,
         label='Y2 values', c='blue', ls='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %%
# first plot
plt.plot(x, y_1, label='Y values',
         color='red', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25) # format the grid, smaller no = fainter grid

# add another plot
plt.plot(x, y_2,
         label='Y2 values', c='blue', ls='solid') # ls is solid by default
plt.legend(loc='upper left') # includes both set of values

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75
plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3,
             xerr=x_error, yerr=y_error,
             label="Y3 with errors",
             color="green") # constant errors for all points
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left') # put at the end to include all plots

# %% [markdown]
# # 2 Better with NumPy

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

import numpy as np # convert phython lists into numpy arrays
np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values') # solid line

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2                  # math function on x
sin_x = np.sin(x)          # np allows math to be done

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed', )
plt.plot(x, sin_x, label='sin(x)',
         color='blue')
plt.legend()                                 

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6]) # inaccuracy in the plot due to limited number of values
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')   # For y-axis 1

plt.twinx()              # This creates a new y-axis 
                         # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')  # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)

# %%
# x = np.array([0, 1, 2, 3, 4, 5, 6])
x = np.arange(0, 6, .5) # using np to give a range
print(x)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc='lower left')   # For y-axis 1

plt.twinx()              # This creates a new y-axis 
                         # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc='lower right')  # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5 5.  5.5]

# %%
# x = np.array([0, 1, 2, 3, 4, 5, 6])
# x = np.arange(0, 6, .5)
x = np.linspace(0, 6, 100) # using np.linspace()
print(x)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc=(.5, .5))   # For y-axis 1

plt.twinx()              # This creates a new y-axis 
                         # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc=(.5, .6))  # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)
# Out:
# [0.         0.06060606 0.12121212 0.18181818 0.24242424 0.3030303
#  0.36363636 0.42424242 0.48484848 0.54545455 0.60606061 0.66666667
#  0.72727273 0.78787879 0.84848485 0.90909091 0.96969697 1.03030303
#  1.09090909 1.15151515 1.21212121 1.27272727 1.33333333 1.39393939
#  1.45454545 1.51515152 1.57575758 1.63636364 1.6969697  1.75757576
#  1.81818182 1.87878788 1.93939394 2.         2.06060606 2.12121212
#  2.18181818 2.24242424 2.3030303  2.36363636 2.42424242 2.48484848
#  2.54545455 2.60606061 2.66666667 2.72727273 2.78787879 2.84848485
#  2.90909091 2.96969697 3.03030303 3.09090909 3.15151515 3.21212121
#  3.27272727 3.33333333 3.39393939 3.45454545 3.51515152 3.57575758
#  3.63636364 3.6969697  3.75757576 3.81818182 3.87878788 3.93939394
#  4.         4.06060606 4.12121212 4.18181818 4.24242424 4.3030303
#  4.36363636 4.42424242 4.48484848 4.54545455 4.60606061 4.66666667
#  4.72727273 4.78787879 4.84848485 4.90909091 4.96969697 5.03030303
#  5.09090909 5.15151515 5.21212121 5.27272727 5.33333333 5.39393939
#  5.45454545 5.51515152 5.57575758 5.63636364 5.6969697  5.75757576
#  5.81818182 5.87878788 5.93939394 6.        ]

# %%
# x = np.array([0, 1, 2, 3, 4, 5, 6])
# x = np.arange(0, 6, .5)
x = np.linspace(0, 6, 100) # using np.linspace()
print(x)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',color='red', linestyle='dashed')
plt.legend(loc=(.25, .5), frameon=False)   # For y-axis 1

plt.twinx()              # This creates a new y-axis 
                         # for the plots that comes after
plt.plot(x, sin_x, label='sin(x)',color='blue', )
plt.legend(loc=(.25, .6), frameon=False)  # For y-axis 2

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)
# Out:
# [0.         0.06060606 0.12121212 0.18181818 0.24242424 0.3030303
#  0.36363636 0.42424242 0.48484848 0.54545455 0.60606061 0.66666667
#  0.72727273 0.78787879 0.84848485 0.90909091 0.96969697 1.03030303
#  1.09090909 1.15151515 1.21212121 1.27272727 1.33333333 1.39393939
#  1.45454545 1.51515152 1.57575758 1.63636364 1.6969697  1.75757576
#  1.81818182 1.87878788 1.93939394 2.         2.06060606 2.12121212
#  2.18181818 2.24242424 2.3030303  2.36363636 2.42424242 2.48484848
#  2.54545455 2.60606061 2.66666667 2.72727273 2.78787879 2.84848485
#  2.90909091 2.96969697 3.03030303 3.09090909 3.15151515 3.21212121
#  3.27272727 3.33333333 3.39393939 3.45454545 3.51515152 3.57575758
#  3.63636364 3.6969697  3.75757576 3.81818182 3.87878788 3.93939394
#  4.         4.06060606 4.12121212 4.18181818 4.24242424 4.3030303
#  4.36363636 4.42424242 4.48484848 4.54545455 4.60606061 4.66666667
#  4.72727273 4.78787879 4.84848485 4.90909091 4.96969697 5.03030303
#  5.09090909 5.15151515 5.21212121 5.27272727 5.33333333 5.39393939
#  5.45454545 5.51515152 5.57575758 5.63636364 5.6969697  5.75757576
#  5.81818182 5.87878788 5.93939394 6.        ]

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2',
         color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x,
         label='sin x', color='blue')
plt.legend(loc='lower right')

plt.xlabel('x-values')
plt.ylabel('math function on x')
plt.title('math function in plot')
plt.grid(alpha=.25)

plt.savefig('simple-plot.png', dpi=150) # save plot to local drive

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3])

plt.xlabel('Years')
plt.ylabel('Change in temperature')
plt.title('Average temperature data for Daily Land')
plt.grid(alpha=.25)

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3])

plt.xlabel('Years')
plt.ylabel('Change in temperature')
plt.title('Average temperature data for Daily Land')
plt.grid(alpha=.25)

# add horizontal line at zero value to highlight trend
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ## 4.2 Styles

# %%
plt.style.use('fivethirtyeight')
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3])

plt.xlabel('Years')
plt.ylabel('Change in temperature')
plt.title('Average temperature data for Daily Land')
plt.grid(alpha=.25)

# add horizontal line at zero value to highlight trend
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3])

plt.xlabel('Years')
plt.ylabel('Change in temperature')
plt.title('Average temperature data for Daily Land')
plt.grid(alpha=.25)

# add horizontal line at zero value to highlight trend
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-3, 3])

plt.xlabel('Years')
plt.ylabel('Change in temperature')
plt.title('Average temperature data for Daily Land')
plt.grid(alpha=.25)

# add horizontal line at zero value to highlight trend
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')
